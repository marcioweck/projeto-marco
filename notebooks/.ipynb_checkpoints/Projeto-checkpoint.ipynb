# %% [markdown]
# Projeto de Interpretação e Classificação dos dados da Camada II-III do NeuronalSys
# ----------------------------------------------------------------------------------
#
# ## Introdução
#
# ### Objetivos
#
# ### Agenda
#
# 1. Leitura dos dados de frequência e análise;
# 2. Interpretação de qual melhor método para ser utilizado;
# 3. Escolha de dois métodos
# 4. Aplicação dos métodos
# 5. Resultados
# 6. Conclusões
#
# ## Obtenção dos dados
#
# Os dados foram obtidos através de uma modificação no NeuronalSys, em que foi possível geral um conjunto de dados para treinamento, teste e validação de métodos de classificação. Esse conjunto foi gerado no formato coluna x linha x tempo. O script (encontrado na pasta scripts) map_reduce.py, converte esses arquivos para uma representação de frequência.
#
# Exemplo de uso do script
# ```bash
# # python map_reduce.py dir_com_arquivos_de_entrada dir_para_arquivos_de_saida
# python map_reduce.py ../data/raw_activation_maps/ ../data/freqs_series/
# ```

# %% [markdown]
# ## Interpretação
#
# O código abaixo será usado pelas outras _cells_ no restante do _notebook_ então é importante que ele seja sempre executado, quando o _notebook_ for atualizado:

# %%
import os

import numpy as np
import pandas as pd

# Visualization
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

shapes = ('square', 'triangle', 'hbar', 'vbar')

# %% [markdown]
# ### Preparando o conjunto de dados

# %%
import glob

FREQS_DATA_DIR = os.path.join('..', 'data', 'freqs_series')
print(FREQS_DATA_DIR)

lsamples = []
class_ = []
for shape in shapes:  
    pattern = os.path.join(FREQS_DATA_DIR, '%s_*.dat' % shape)
    print(pattern)
    files = glob.glob(pattern)    
    
    for i, filename in enumerate(files):
        sdf = pd.read_csv(filename, sep=',', header=None, names=['time', 'freq'])
        sample = np.zeros(3000)
        sample[sdf.time] = sdf.freq
        lsamples.append(sample)
        class_.append(shape)
    
df = np.array(lsamples)
cldf = np.array(class_)
# Out:
# ../data/freqs_series
# ../data/freqs_series/square_*.dat
# ../data/freqs_series/triangle_*.dat
# ../data/freqs_series/hbar_*.dat
# ../data/freqs_series/vbar_*.dat

# %% [markdown]
# ### Visualização

# %%
fig = plt.figure(figsize=(12, 6))
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)
_ = ax1.plot(df[cldf == 'square',:].T, '.', label='square')
_ = ax2.plot(df[cldf == 'triangle',:].T, '.', label='triangle') 
_ = ax3.plot(df[cldf == 'vbar',:].T, '.', label='vbar')
_ = ax4.plot(df[cldf == 'hbar',:].T, '.', label='hbar')

plt.figure(figsize=(11,7))
colors = ['#D62728','#2C9F2C','#FD7F23','#1F77B4']

for i, r in enumerate([10, 220, 350, 500]):
    plt.subplot(2,2,i+1)
    plt.plot(df[r, :], label=cldf[r], color=colors[i], linewidth=2)
    plt.xlabel('Samples')
    plt.legend(loc='upper left')
    plt.tight_layout()

# %% [markdown]
# ### Análise do Sinal

# %%
from scipy import signal

# sig_id = cldf == 'vbar'
# sig = df[sig_id.argsort()[-5],:]
# print(cldf[sig_id.argsort()[-4]])
# print(sig.shape)
sig = df[cldf == 'vbar', :]
t = range(3000)

plt.figure(0)
widths = np.arange(1, 31)
for s in sig:
    cwtmatr = signal.cwt(s, signal.ricker, widths)
    select = 3
    plt.plot(t[50:-50], np.abs(cwtmatr[select-1, 50:-50]), label=select)
plt.show()


sig = df[cldf == 'triangle', :]
t = range(3000)

plt.figure(1)
widths = np.arange(1, 31)
for s in sig:
    cwtmatr = signal.cwt(s, signal.ricker, widths)
    select = 3
    plt.plot(t[50:-50], np.abs(cwtmatr[select-1, 50:-50]), label=select)
plt.show()

plt.figure(2)
plt.imshow(cwtmatr, extent=[-1, 1, 1, 31], cmap='PRGn', aspect='auto',
           vmax=abs(cwtmatr).max(), vmin=-abs(cwtmatr).max())

# %% [markdown]
# ## Classificador
#
# ### Métrica - Dynamic Time Warping (DTW)
#
# Dynamic time warping (DTW) é um algoritmo usado para comparar e alinhar duas séries temporais. Com ele é possível obter o alinhamento não-linear ótimo entre duas sequências de valores numéricos. Dessa maneira, é possível encontrar padrões entre medições de eventos com diferentes ritmos.
#
# O DTW é um algoritmo de complexidade alta (O(N^2)), o que pode torná-lo lento quando a janela ou o tamanho da série é muito grande. Algumas implementações possuem otimizações que reduzem o custo computacional. No caso deste projeto foi utilizada a FastDTW.
#
# Pseudo código:
# ```
# int DTWDistance(s: array [1..n], t: array [1..m]) {
#    DTW := array [0..n, 0..m]
#
#    for i := 1 to n
#        DTW[i, 0] := infinity
#    for i := 1 to m
#        DTW[0, i] := infinity
#    DTW[0, 0] := 0
#
#    for i := 1 to n
#        for j := 1 to m
#            cost := d(s[i], t[j])
#            DTW[i, j] := cost + minimum(DTW[i-1, j  ],    // insertion
#                                        DTW[i  , j-1],    // deletion
#                                        DTW[i-1, j-1])    // match
#
#    return DTW[n, m]
# }
# ```
#
# ### Agrupador - K-Nearest Neighbors Algorithm (K-NN)
#
# K-Nearest Neighbor é um algoritmo utilizado para classificação e regressão. Em ambos os casos, o método consiste em encontrar "k" exemplos de treinamento mais próximos no espaço de busca. A saida depende do objetivo, como estamos trabalhando com classificação, a saída é a classe a qual o exemplo apresentado pertence.
#
# ### Implementação KNN-DTW
#
# A implementação completa do móudlo que combina o agrupador (KNN) com a métrica de distância para séries temporais (DTW) se encontra no directório _scripts_ no arquivo _project.py_.

# %% [markdown]
# Exemplo da distância DTW aplicada a duas senoides:

# %%
from functools import lru_cache
from scipy.stats import mode
import sys

have_ipython=True

class ProgressBar:
    """This progress bar was taken from PYMC
    """
    def __init__(self, iterations):
        self.iterations = iterations
        self.prog_bar = '[]'
        self.fill_char = '*'
        self.width = 40
        self.__update_amount(0)
        if have_ipython:
            self.animate = self.animate_ipython
        else:
            self.animate = self.animate_noipython

    def animate_ipython(self, iter):
        print('\r', self)
        sys.stdout.flush()
        self.update_iteration(iter + 1)

    def update_iteration(self, elapsed_iter):
        self.__update_amount((elapsed_iter / float(self.iterations)) * 100.0)
        self.prog_bar += '  %d of %s complete' % (elapsed_iter, self.iterations)

    def __update_amount(self, new_amount):
        percent_done = int(round((new_amount / 100.0) * 100.0))
        all_full = self.width - 2
        num_hashes = int(round((percent_done / 100.0) * all_full))
        self.prog_bar = '[' + self.fill_char * num_hashes + ' ' * (all_full - num_hashes) + ']'
        pct_place = (len(self.prog_bar) // 2) - len(str(percent_done))
        pct_string = '%d%%' % percent_done
        self.prog_bar = self.prog_bar[0:pct_place] + \
            (pct_string + self.prog_bar[pct_place + len(pct_string):])

    def __str__(self):
        return str(self.prog_bar)


@lru_cache(maxsize=None)
def dist(a, b):
    return np.linalg.norm(a-b)

def dtw_distance(ts_a, ts_b, max_warping_window=100):
    """Returns the DTW similarity distance between two 2-D
    timeseries numpy arrays.

    Arguments
    ---------
    ts_a, ts_b : array of shape [n_samples, n_timepoints]
        Two arrays containing n_samples of timeseries data
        whose DTW distance between each sample of A and B
        will be compared

    d : DistanceMetric object (default = abs(x-y))
        the distance measure used for A_i - B_j in the
        DTW dynamic programming function

    Returns
    -------
    DTW distance between A and B
    """

    # Create cost matrix via broadcasting with large int
    ts_a, ts_b = np.array(ts_a), np.array(ts_b)
    M, N = len(ts_a), len(ts_b)
    cost = sys.maxsize * np.ones((M, N))
    
    # Initialize the first row and column
    cost[0, 0] = dist(ts_a[0], ts_b[0])
    cost[1:, 0] = [cost[i-1, 0] + dist(ts_a[i], ts_b[0]) for i in range(1, M)]

    cost[0, 1:] = [cost[0, j-1] + dist(ts_a[0], ts_b[j]) for j in range(1, N)]

    # Populate rest of cost matrix within window
    for i in range(1, M):
        for j in range(max(1, i - max_warping_window),
                        min(N, i + max_warping_window)):
            choices = cost[i - 1, j - 1], cost[i, j-1], cost[i-1, j]
            cost[i, j] = min(choices) + dist(ts_a[i], ts_b[j])

    # Return DTW distance given window
    return cost[-1, -1]


def dist_matrix(x, y, subsample_step=1, warping_window_sz=100):
    """Computes the M x N distance matrix between the training
    dataset and testing dataset (y) using the DTW distance measure

    Arguments
    ---------
    x : array of shape [n_samples, n_timepoints]

    y : array of shape [n_samples, n_timepoints]

    Returns
    -------
    Distance matrix between each item of x and y with
        shape [training_n_samples, testing_n_samples]
    """

    # Compute the distance matrix
    dm_count = 0

    # Compute condensed distance matrix (upper triangle) of pairwise dtw distances
    # when x and y are the same array
    if(np.array_equal(x, y)):
        x_s = x.shape
        dm = np.zeros((x_s[0] * (x_s[0] - 1)) // 2, dtype=np.double)

        p = ProgressBar(dm.shape[0])

        for i in range(0, x_s[0] - 1):
            for j in range(i + 1, x_s[0]):
                dm[dm_count] = dtw_distance(x[i, ::subsample_step],
                                                  y[j, ::subsample_step], warping_window_sz)

                dm_count += 1
                p.animate(dm_count)

        # Convert to squareform
        dm = squareform(dm)
        return dm

    # Compute full distance matrix of dtw distnces between x and y
    else:
        x_s = np.shape(x)
        y_s = np.shape(y)
        dm = np.zeros((x_s[0], y_s[0]))
        dm_size = x_s[0]*y_s[0]

        p = ProgressBar(dm_size)

        for i in range(0, x_s[0]):
            for j in range(0, y_s[0]):
                dm[i, j] = dtw_distance(x[i, ::subsample_step],
                                              y[j, ::subsample_step], warping_window_sz)
                # Update progress bar
                dm_count += 1
                p.animate(dm_count)

        return dm
    
def most_common(coll):
    lst = list(coll)
    return max(lst, key=lst.count)

def centroid(arr):
    length = arr.shape[0]
    sum_x = np.sum(arr[:, 0])
    sum_y = np.sum(arr[:, 1])
    return sum_x/length, sum_y/length

def predict(x, t_x, l, n_neighbors=1, warping_window_sz=100):
    """Predict the class labels or probability estimates for
    the provided data

    Arguments
    ---------
      x : array of shape [n_samples, n_timepoints]
          Array containing the testing data set to be classified

    Returns
    -------
      2 arrays representing:
          (1) the predicted class labels
          (2) the knn label count probability
    """
    
    from sklearn.cluster import KMeans
    kmeans = KMeans(n_clusters=12).fit(t_x)
    cluster_centers = kmeans.cluster_centers_
    kl = np.array([most_common(l[kmeans.labels_==i]) for i in range(len(cluster_centers))])
          
    dm = dist_matrix(x, cluster_centers, warping_window_sz=warping_window_sz)
    print(dm)
    # Identify the k nearest neighbors
    knn_idx = dm.argsort()[:, :n_neighbors]
    print(knn_idx)

    # Identify k nearest labels
    knn_labels = kl[knn_idx]

    # Model Label
    mode_data = mode(knn_labels, axis=1)
    mode_label = mode_data[0]
    mode_proba = mode_data[1]/n_neighbors

    return mode_label.ravel(), mode_proba.ravel()

# %%
time = np.linspace(0,20,1000)
amplitude_a = 7.2*np.sin(time)
amplitude_b = 4.3*np.sin(time + 1)

distance = dtw_distance(amplitude_a, amplitude_b, int(len(time)*0.1))

fig = plt.figure(figsize=(12,4))
_ = plt.plot(time, amplitude_a, label='A')
_ = plt.plot(time, amplitude_b, label='B')
_ = plt.title('Distância DTW entre A e B é %.2f' % distance)
_ = plt.ylabel('Amplitude')
_ = plt.xlabel('Tempo')
_ = plt.legend()

# %%
# Remove o excesso de zeros

start_j = 0
print(df.shape)
for j in range(df.shape[1]):
    if df[:,j].any():
        start_j = j-min(10, j)
        break
    
end_j = 0
for j in range(df.shape[1]-1, 0, -1):
    if df[:,j].any():
        end_j = j+min(10, df.shape[1]-j)
        break

df = df[:, start_j:end_j]

x_train = [] #df[chosen,:]
y_train = [] #cldf[chosen]

x_test = [] #df[test_chosen,:]
y_test = [] #cldf[test_chosen]
    
for shape in shapes:
    mask = cldf == shape
    indexes = np.arange(df.shape[0])[mask]
    chosen = np.random.choice(indexes, replace=False, size=int(len(indexes)*0.6))
    test_chosen = [idx for idx in indexes if idx not in chosen]

    x_train.extend([df[i,:] for i in chosen])
    y_train.extend([cldf[i] for i in chosen])

    x_test.extend([df[i,:] for i in test_chosen])
    y_test.extend([cldf[i] for i in test_chosen])
    
x_train = np.array(x_train)
y_train = np.array(y_train)

x_test = np.array(x_test)
y_test = np.array(y_test)

y_train[y_train=='hbar'] = 'bar'
y_train[y_train=='vbar'] = 'bar'
y_test[y_test=='hbar'] = 'bar'
y_test[y_test=='vbar'] = 'bar'

print(x_test.shape)
# Out:
# (591, 1683)
# (237, 1683)

# %%
step = 1

warping_win_sz = 168
label, proba = predict(x_test[::step], 
                       x_train[::step], y_train[::step], 
                       warping_window_sz = warping_win_sz)
# Out:
#  [                  0%                  ]
#  [                  0%                  ]  2 of 2844 complete
#  [                  0%                  ]  3 of 2844 complete
#  [                  0%                  ]  4 of 2844 complete
#  [                  0%                  ]  5 of 2844 complete
#  [                  0%                  ]  6 of 2844 complete
#  [                  0%                  ]  7 of 2844 complete
#  [                  0%                  ]  8 of 2844 complete
#  [                  0%                  ]  9 of 2844 complete
#  [                  0%                  ]  10 of 2844 complete
#  [                  0%                  ]  11 of 2844 complete
#  [                  0%                  ]  12 of 2844 complete
#  [                  0%                  ]  13 of 2844 complete
#  [                  0%                  ]  14 of 2844 complete
#  [                  1%                  ]  15 of 2844 complete
#  [                  1%                  ]  16 of 2844 complete
#  [                  1%                  ]  17 of 2844 complete
#  [                  1%                  ]  18 of 2844 complete
#  [                  1%                  ]  19 of 2844 complete
#  [                  1%                  ]  20 of 2844 complete
#  [                  1%                  ]  21 of 2844 complete
#  [                  1%                  ]  22 of 2844 complete
#  [                  1%                  ]  23 of 2844 complete
#  [                  1%                  ]  24 of 2844 complete
#  [                  1%                  ]  25 of 2844 complete
#  [                  1%                  ]  26 of 2844 complete
#  [                  1%                  ]  27 of 2844 complete
#  [                  1%                  ]  28 of 2844 complete
#  [                  1%                  ]  29 of 2844 complete
#  [                  1%                  ]  30 of 2844 complete
#  [                  1%                  ]  31 of 2844 complete
#  [                  1%                  ]  32 of 2844 complete
#  [                  1%                  ]  33 of 2844 complete
#  [                  1%                  ]  34 of 2844 complete
#  [                  1%                  ]  35 of 2844 complete
#  [                  1%                  ]  36 of 2844 complete
#  [                  1%                  ]  37 of 2844 complete
#  [                  1%                  ]  38 of 2844 complete
#  [                  1%                  ]  39 of 2844 complete
#  [                  1%                  ]  40 of 2844 complete
#  [                  1%                  ]  41 of 2844 complete
#  [                  1%                  ]  42 of 2844 complete
#  [*                 2%                  ]  43 of 2844 complete
#  [*                 2%                  ]  44 of 2844 complete
#  [*                 2%                  ]  45 of 2844 complete
#  [*                 2%                  ]  46 of 2844 complete
#  [*                 2%                  ]  47 of 2844 complete
#  [*                 2%                  ]  48 of 2844 complete
#  [*                 2%                  ]  49 of 2844 complete
#  [*                 2%                  ]  50 of 2844 complete
#  [*                 2%                  ]  51 of 2844 complete
#  [*                 2%                  ]  52 of 2844 complete
#  [*                 2%                  ]  53 of 2844 complete
#  [*                 2%                  ]  54 of 2844 complete
#  [*                 2%                  ]  55 of 2844 complete
#  [*                 2%                  ]  56 of 2844 complete
#  [*                 2%                  ]  57 of 2844 complete
#  [*                 2%                  ]  58 of 2844 complete
#  [*                 2%                  ]  59 of 2844 complete
#  [*                 2%                  ]  60 of 2844 complete
#  [*                 2%                  ]  61 of 2844 complete
#  [*                 2%                  ]  62 of 2844 complete
#  [*                 2%                  ]  63 of 2844 complete
#  [*                 2%                  ]  64 of 2844 complete
#  [*                 2%                  ]  65 of 2844 complete
#  [*                 2%                  ]  66 of 2844 complete
#  [*                 2%                  ]  67 of 2844 complete
#  [*                 2%                  ]  68 of 2844 complete
#  [*                 2%                  ]  69 of 2844 complete
#  [*                 2%                  ]  70 of 2844 complete
#  [*                 2%                  ]  71 of 2844 complete
#  [*                 3%                  ]  72 of 2844 complete
#  [*                 3%                  ]  73 of 2844 complete
#  [*                 3%                  ]  74 of 2844 complete
#  [*                 3%                  ]  75 of 2844 complete
#  [*                 3%                  ]  76 of 2844 complete
#  [*                 3%                  ]  77 of 2844 complete
#  [*                 3%                  ]  78 of 2844 complete
#  [*                 3%                  ]  79 of 2844 complete
#  [*                 3%                  ]  80 of 2844 complete
#  [*                 3%                  ]  81 of 2844 complete
#  [*                 3%                  ]  82 of 2844 complete
#  [*                 3%                  ]  83 of 2844 complete
#  [*                 3%                  ]  84 of 2844 complete
#  [*                 3%                  ]  85 of 2844 complete
#  [*                 3%                  ]  86 of 2844 complete
#  [*                 3%                  ]  87 of 2844 complete
#  [*                 3%                  ]  88 of 2844 complete
#  [*                 3%                  ]  89 of 2844 complete
#  [*                 3%                  ]  90 of 2844 complete
#  [*                 3%                  ]  91 of 2844 complete
#  [*                 3%                  ]  92 of 2844 complete
#  [*                 3%                  ]  93 of 2844 complete
#  [*                 3%                  ]  94 of 2844 complete
#  [*                 3%                  ]  95 of 2844 complete
#  [*                 3%                  ]  96 of 2844 complete
#  [*                 3%                  ]  97 of 2844 complete
#  [*                 3%                  ]  98 of 2844 complete
#  [*                 3%                  ]  99 of 2844 complete
#  [**                4%                  ]  100 of 2844 complete
#  [**                4%                  ]  101 of 2844 complete
#  [**                4%                  ]  102 of 2844 complete
#  [**                4%                  ]  103 of 2844 complete
#  [**                4%                  ]  104 of 2844 complete
#  [**                4%                  ]  105 of 2844 complete
#  [**                4%                  ]  106 of 2844 complete
#  [**                4%                  ]  107 of 2844 complete
#  [**                4%                  ]  108 of 2844 complete
#  [**                4%                  ]  109 of 2844 complete
#  [**                4%                  ]  110 of 2844 complete
#  [**                4%                  ]  111 of 2844 complete
#  [**                4%                  ]  112 of 2844 complete
#  [**                4%                  ]  113 of 2844 complete
#  [**                4%                  ]  114 of 2844 complete
#  [**                4%                  ]  115 of 2844 complete
#  [**                4%                  ]  116 of 2844 complete
#  [**                4%                  ]  117 of 2844 complete
#  [**                4%                  ]  118 of 2844 complete
#  [**                4%                  ]  119 of 2844 complete
#  [**                4%                  ]  120 of 2844 complete
#  [**                4%                  ]  121 of 2844 complete
#  [**                4%                  ]  122 of 2844 complete
#  [**                4%                  ]  123 of 2844 complete
#  [**                4%                  ]  124 of 2844 complete
#  [**                4%                  ]  125 of 2844 complete
#  [**                4%                  ]  126 of 2844 complete
#  [**                4%                  ]  127 of 2844 complete
#  [**                5%                  ]  128 of 2844 complete
#  [**                5%                  ]  129 of 2844 complete
#  [**                5%                  ]  130 of 2844 complete
#  [**                5%                  ]  131 of 2844 complete
#  [**                5%                  ]  132 of 2844 complete
#  [**                5%                  ]  133 of 2844 complete
#  [**                5%                  ]  134 of 2844 complete
#  [**                5%                  ]  135 of 2844 complete
#  [**                5%                  ]  136 of 2844 complete
#  [**                5%                  ]  137 of 2844 complete
#  [**                5%                  ]  138 of 2844 complete
#  [**                5%                  ]  139 of 2844 complete
#  [**                5%                  ]  140 of 2844 complete
#  [**                5%                  ]  141 of 2844 complete
#  [**                5%                  ]  142 of 2844 complete
#  [**                5%                  ]  143 of 2844 complete
#  [**                5%                  ]  144 of 2844 complete
#  [**                5%                  ]  145 of 2844 complete
#  [**                5%                  ]  146 of 2844 complete
#  [**                5%                  ]  147 of 2844 complete
#  [**                5%                  ]  148 of 2844 complete
#  [**                5%                  ]  149 of 2844 complete
#  [**                5%                  ]  150 of 2844 complete
#  [**                5%                  ]  151 of 2844 complete
#  [**                5%                  ]  152 of 2844 complete
#  [**                5%                  ]  153 of 2844 complete
#  [**                5%                  ]  154 of 2844 complete
#  [**                5%                  ]  155 of 2844 complete
#  [**                5%                  ]  156 of 2844 complete
#  [**                6%                  ]  157 of 2844 complete
#  [**                6%                  ]  158 of 2844 complete
#  [**                6%                  ]  159 of 2844 complete
#  [**                6%                  ]  160 of 2844 complete
#  [**                6%                  ]  161 of 2844 complete
#  [**                6%                  ]  162 of 2844 complete
#  [**                6%                  ]  163 of 2844 complete
#  [**                6%                  ]  164 of 2844 complete
#  [**                6%                  ]  165 of 2844 complete
#  [**                6%                  ]  166 of 2844 complete
#  [**                6%                  ]  167 of 2844 complete
#  [**                6%                  ]  168 of 2844 complete
#  [**                6%                  ]  169 of 2844 complete
#  [**                6%                  ]  170 of 2844 complete
#  [**                6%                  ]  171 of 2844 complete
#  [**                6%                  ]  172 of 2844 complete
#  [**                6%                  ]  173 of 2844 complete
#  [**                6%                  ]  174 of 2844 complete
#  [**                6%                  ]  175 of 2844 complete
#  [**                6%                  ]  176 of 2844 complete
#  [**                6%                  ]  177 of 2844 complete
#  [**                6%                  ]  178 of 2844 complete
#  [**                6%                  ]  179 of 2844 complete
#  [**                6%                  ]  180 of 2844 complete
#  [**                6%                  ]  181 of 2844 complete
#  [**                6%                  ]  182 of 2844 complete
#  [**                6%                  ]  183 of 2844 complete
#  [**                6%                  ]  184 of 2844 complete
#  [***               7%                  ]  185 of 2844 complete
#  [***               7%                  ]  186 of 2844 complete
#  [***               7%                  ]  187 of 2844 complete
#  [***               7%                  ]  188 of 2844 complete
#  [***               7%                  ]  189 of 2844 complete
#  [***               7%                  ]  190 of 2844 complete
#  [***               7%                  ]  191 of 2844 complete
#  [***               7%                  ]  192 of 2844 complete
#  [***               7%                  ]  193 of 2844 complete
#  [***               7%                  ]  194 of 2844 complete
#  [***               7%                  ]  195 of 2844 complete
#  [***               7%                  ]  196 of 2844 complete
#  [***               7%                  ]  197 of 2844 complete
#  [***               7%                  ]  198 of 2844 complete
#  [***               7%                  ]  199 of 2844 complete
#  [***               7%                  ]  200 of 2844 complete
#  [***               7%                  ]  201 of 2844 complete
#  [***               7%                  ]  202 of 2844 complete
#  [***               7%                  ]  203 of 2844 complete
#  [***               7%                  ]  204 of 2844 complete
#  [***               7%                  ]  205 of 2844 complete
#  [***               7%                  ]  206 of 2844 complete
#  [***               7%                  ]  207 of 2844 complete
#  [***               7%                  ]  208 of 2844 complete
#  [***               7%                  ]  209 of 2844 complete
#  [***               7%                  ]  210 of 2844 complete
#  [***               7%                  ]  211 of 2844 complete
#  [***               7%                  ]  212 of 2844 complete
#  [***               7%                  ]  213 of 2844 complete
#  [***               8%                  ]  214 of 2844 complete
#  [***               8%                  ]  215 of 2844 complete
#  [***               8%                  ]  216 of 2844 complete
#  [***               8%                  ]  217 of 2844 complete
#  [***               8%                  ]  218 of 2844 complete
#  [***               8%                  ]  219 of 2844 complete
#  [***               8%                  ]  220 of 2844 complete
#  [***               8%                  ]  221 of 2844 complete
#  [***               8%                  ]  222 of 2844 complete
#  [***               8%                  ]  223 of 2844 complete
#  [***               8%                  ]  224 of 2844 complete
#  [***               8%                  ]  225 of 2844 complete
#  [***               8%                  ]  226 of 2844 complete
#  [***               8%                  ]  227 of 2844 complete
#  [***               8%                  ]  228 of 2844 complete
#  [***               8%                  ]  229 of 2844 complete
#  [***               8%                  ]  230 of 2844 complete
#  [***               8%                  ]  231 of 2844 complete
#  [***               8%                  ]  232 of 2844 complete
#  [***               8%                  ]  233 of 2844 complete
#  [***               8%                  ]  234 of 2844 complete
#  [***               8%                  ]  235 of 2844 complete
#  [***               8%                  ]  236 of 2844 complete
#  [***               8%                  ]  237 of 2844 complete
#  [***               8%                  ]  238 of 2844 complete
#  [***               8%                  ]  239 of 2844 complete
#  [***               8%                  ]  240 of 2844 complete
#  [***               8%                  ]  241 of 2844 complete
#  [***               9%                  ]  242 of 2844 complete
#  [***               9%                  ]  243 of 2844 complete
#  [***               9%                  ]  244 of 2844 complete
#  [***               9%                  ]  245 of 2844 complete
#  [***               9%                  ]  246 of 2844 complete
#  [***               9%                  ]  247 of 2844 complete
#  [***               9%                  ]  248 of 2844 complete
#  [***               9%                  ]  249 of 2844 complete
#  [***               9%                  ]  250 of 2844 complete
#  [***               9%                  ]  251 of 2844 complete
#  [***               9%                  ]  252 of 2844 complete
#  [***               9%                  ]  253 of 2844 complete
#  [***               9%                  ]  254 of 2844 complete
#  [***               9%                  ]  255 of 2844 complete
#  [***               9%                  ]  256 of 2844 complete
#  [***               9%                  ]  257 of 2844 complete
#  [***               9%                  ]  258 of 2844 complete
#  [***               9%                  ]  259 of 2844 complete
#  [***               9%                  ]  260 of 2844 complete
#  [***               9%                  ]  261 of 2844 complete
#  [***               9%                  ]  262 of 2844 complete
#  [***               9%                  ]  263 of 2844 complete
#  [***               9%                  ]  264 of 2844 complete
#  [***               9%                  ]  265 of 2844 complete
#  [***               9%                  ]  266 of 2844 complete
#  [***               9%                  ]  267 of 2844 complete
#  [***               9%                  ]  268 of 2844 complete
#  [***               9%                  ]  269 of 2844 complete
#  [***               9%                  ]  270 of 2844 complete
#  [****             10%                  ]  271 of 2844 complete
#  [****             10%                  ]  272 of 2844 complete
#  [****             10%                  ]  273 of 2844 complete
#  [****             10%                  ]  274 of 2844 complete
#  [****             10%                  ]  275 of 2844 complete
#  [****             10%                  ]  276 of 2844 complete
#  [****             10%                  ]  277 of 2844 complete
#  [****             10%                  ]  278 of 2844 complete
#  [****             10%                  ]  279 of 2844 complete
#  [****             10%                  ]  280 of 2844 complete
#  [****             10%                  ]  281 of 2844 complete
#  [****             10%                  ]  282 of 2844 complete
#  [****             10%                  ]  283 of 2844 complete
#  [****             10%                  ]  284 of 2844 complete
#  [****             10%                  ]  285 of 2844 complete
#  [****             10%                  ]  286 of 2844 complete
#  [****             10%                  ]  287 of 2844 complete
#  [****             10%                  ]  288 of 2844 complete
#  [****             10%                  ]  289 of 2844 complete
#  [****             10%                  ]  290 of 2844 complete
#  [****             10%                  ]  291 of 2844 complete
#  [****             10%                  ]  292 of 2844 complete
#  [****             10%                  ]  293 of 2844 complete
#  [****             10%                  ]  294 of 2844 complete
#  [****             10%                  ]  295 of 2844 complete
#  [****             10%                  ]  296 of 2844 complete
#  [****             10%                  ]  297 of 2844 complete
#  [****             10%                  ]  298 of 2844 complete
#  [****             11%                  ]  299 of 2844 complete
#  [****             11%                  ]  300 of 2844 complete
#  [****             11%                  ]  301 of 2844 complete
#  [****             11%                  ]  302 of 2844 complete
#  [****             11%                  ]  303 of 2844 complete
#  [****             11%                  ]  304 of 2844 complete
#  [****             11%                  ]  305 of 2844 complete
#  [****             11%                  ]  306 of 2844 complete
#  [****             11%                  ]  307 of 2844 complete
#  [****             11%                  ]  308 of 2844 complete
#  [****             11%                  ]  309 of 2844 complete
#  [****             11%                  ]  310 of 2844 complete
#  [****             11%                  ]  311 of 2844 complete
#  [****             11%                  ]  312 of 2844 complete
#  [****             11%                  ]  313 of 2844 complete
#  [****             11%                  ]  314 of 2844 complete
#  [****             11%                  ]  315 of 2844 complete
#  [****             11%                  ]  316 of 2844 complete
#  [****             11%                  ]  317 of 2844 complete
#  [****             11%                  ]  318 of 2844 complete
#  [****             11%                  ]  319 of 2844 complete
#  [****             11%                  ]  320 of 2844 complete
#  [****             11%                  ]  321 of 2844 complete
#  [****             11%                  ]  322 of 2844 complete
#  [****             11%                  ]  323 of 2844 complete
#  [****             11%                  ]  324 of 2844 complete
#  [****             11%                  ]  325 of 2844 complete
#  [****             11%                  ]  326 of 2844 complete
#  [****             11%                  ]  327 of 2844 complete
#  [*****            12%                  ]  328 of 2844 complete
#  [*****            12%                  ]  329 of 2844 complete
#  [*****            12%                  ]  330 of 2844 complete
#  [*****            12%                  ]  331 of 2844 complete
#  [*****            12%                  ]  332 of 2844 complete
#  [*****            12%                  ]  333 of 2844 complete
#  [*****            12%                  ]  334 of 2844 complete
#  [*****            12%                  ]  335 of 2844 complete
#  [*****            12%                  ]  336 of 2844 complete
#  [*****            12%                  ]  337 of 2844 complete
#  [*****            12%                  ]  338 of 2844 complete
#  [*****            12%                  ]  339 of 2844 complete
#  [*****            12%                  ]  340 of 2844 complete
#  [*****            12%                  ]  341 of 2844 complete
#  [*****            12%                  ]  342 of 2844 complete
#  [*****            12%                  ]  343 of 2844 complete
#  [*****            12%                  ]  344 of 2844 complete
#  [*****            12%                  ]  345 of 2844 complete
#  [*****            12%                  ]  346 of 2844 complete
#  [*****            12%                  ]  347 of 2844 complete
#  [*****            12%                  ]  348 of 2844 complete
#  [*****            12%                  ]  349 of 2844 complete
#  [*****            12%                  ]  350 of 2844 complete
#  [*****            12%                  ]  351 of 2844 complete
#  [*****            12%                  ]  352 of 2844 complete
#  [*****            12%                  ]  353 of 2844 complete
#  [*****            12%                  ]  354 of 2844 complete
#  [*****            12%                  ]  355 of 2844 complete
#  [*****            13%                  ]  356 of 2844 complete
#  [*****            13%                  ]  357 of 2844 complete
#  [*****            13%                  ]  358 of 2844 complete
#  [*****            13%                  ]  359 of 2844 complete
#  [*****            13%                  ]  360 of 2844 complete
#  [*****            13%                  ]  361 of 2844 complete
#  [*****            13%                  ]  362 of 2844 complete
#  [*****            13%                  ]  363 of 2844 complete
#  [*****            13%                  ]  364 of 2844 complete
#  [*****            13%                  ]  365 of 2844 complete
#  [*****            13%                  ]  366 of 2844 complete
#  [*****            13%                  ]  367 of 2844 complete
#  [*****            13%                  ]  368 of 2844 complete
#  [*****            13%                  ]  369 of 2844 complete
#  [*****            13%                  ]  370 of 2844 complete
#  [*****            13%                  ]  371 of 2844 complete
#  [*****            13%                  ]  372 of 2844 complete
#  [*****            13%                  ]  373 of 2844 complete
#  [*****            13%                  ]  374 of 2844 complete
#  [*****            13%                  ]  375 of 2844 complete
#  [*****            13%                  ]  376 of 2844 complete
#  [*****            13%                  ]  377 of 2844 complete
#  [*****            13%                  ]  378 of 2844 complete
#  [*****            13%                  ]  379 of 2844 complete
#  [*****            13%                  ]  380 of 2844 complete
#  [*****            13%                  ]  381 of 2844 complete
#  [*****            13%                  ]  382 of 2844 complete
#  [*****            13%                  ]  383 of 2844 complete
#  [*****            14%                  ]  384 of 2844 complete
#  [*****            14%                  ]  385 of 2844 complete
#  [*****            14%                  ]  386 of 2844 complete
#  [*****            14%                  ]  387 of 2844 complete
#  [*****            14%                  ]  388 of 2844 complete
#  [*****            14%                  ]  389 of 2844 complete
#  [*****            14%                  ]  390 of 2844 complete
#  [*****            14%                  ]  391 of 2844 complete
#  [*****            14%                  ]  392 of 2844 complete
#  [*****            14%                  ]  393 of 2844 complete
#  [*****            14%                  ]  394 of 2844 complete
#  [*****            14%                  ]  395 of 2844 complete
#  [*****            14%                  ]  396 of 2844 complete
#  [*****            14%                  ]  397 of 2844 complete
#  [*****            14%                  ]  398 of 2844 complete
#  [*****            14%                  ]  399 of 2844 complete
#  [*****            14%                  ]  400 of 2844 complete
#  [*****            14%                  ]  401 of 2844 complete
#  [*****            14%                  ]  402 of 2844 complete
#  [*****            14%                  ]  403 of 2844 complete
#  [*****            14%                  ]  404 of 2844 complete
#  [*****            14%                  ]  405 of 2844 complete
#  [*****            14%                  ]  406 of 2844 complete
#  [*****            14%                  ]  407 of 2844 complete
#  [*****            14%                  ]  408 of 2844 complete
#  [*****            14%                  ]  409 of 2844 complete
#  [*****            14%                  ]  410 of 2844 complete
#  [*****            14%                  ]  411 of 2844 complete
#  [*****            14%                  ]  412 of 2844 complete
#  [******           15%                  ]  413 of 2844 complete
#  [******           15%                  ]  414 of 2844 complete
#  [******           15%                  ]  415 of 2844 complete
#  [******           15%                  ]  416 of 2844 complete
#  [******           15%                  ]  417 of 2844 complete
#  [******           15%                  ]  418 of 2844 complete
#  [******           15%                  ]  419 of 2844 complete
#  [******           15%                  ]  420 of 2844 complete
#  [******           15%                  ]  421 of 2844 complete
#  [******           15%                  ]  422 of 2844 complete
#  [******           15%                  ]  423 of 2844 complete
#  [******           15%                  ]  424 of 2844 complete
#  [******           15%                  ]  425 of 2844 complete
#  [******           15%                  ]  426 of 2844 complete
#  [******           15%                  ]  427 of 2844 complete
#  [******           15%                  ]  428 of 2844 complete
#  [******           15%                  ]  429 of 2844 complete
#  [******           15%                  ]  430 of 2844 complete
#  [******           15%                  ]  431 of 2844 complete
#  [******           15%                  ]  432 of 2844 complete
#  [******           15%                  ]  433 of 2844 complete
#  [******           15%                  ]  434 of 2844 complete
#  [******           15%                  ]  435 of 2844 complete
#  [******           15%                  ]  436 of 2844 complete
#  [******           15%                  ]  437 of 2844 complete
#  [******           15%                  ]  438 of 2844 complete
#  [******           15%                  ]  439 of 2844 complete
#  [******           15%                  ]  440 of 2844 complete
#  [******           16%                  ]  441 of 2844 complete
#  [******           16%                  ]  442 of 2844 complete
#  [******           16%                  ]  443 of 2844 complete
#  [******           16%                  ]  444 of 2844 complete
#  [******           16%                  ]  445 of 2844 complete
#  [******           16%                  ]  446 of 2844 complete
#  [******           16%                  ]  447 of 2844 complete
#  [******           16%                  ]  448 of 2844 complete
#  [******           16%                  ]  449 of 2844 complete
#  [******           16%                  ]  450 of 2844 complete
#  [******           16%                  ]  451 of 2844 complete
#  [******           16%                  ]  452 of 2844 complete
#  [******           16%                  ]  453 of 2844 complete
#  [******           16%                  ]  454 of 2844 complete
#  [******           16%                  ]  455 of 2844 complete
#  [******           16%                  ]  456 of 2844 complete
#  [******           16%                  ]  457 of 2844 complete
#  [******           16%                  ]  458 of 2844 complete
#  [******           16%                  ]  459 of 2844 complete
#  [******           16%                  ]  460 of 2844 complete
#  [******           16%                  ]  461 of 2844 complete
#  [******           16%                  ]  462 of 2844 complete
#  [******           16%                  ]  463 of 2844 complete
#  [******           16%                  ]  464 of 2844 complete
#  [******           16%                  ]  465 of 2844 complete
#  [******           16%                  ]  466 of 2844 complete
#  [******           16%                  ]  467 of 2844 complete
#  [******           16%                  ]  468 of 2844 complete
#  [******           16%                  ]  469 of 2844 complete
#  [******           17%                  ]  470 of 2844 complete
#  [******           17%                  ]  471 of 2844 complete
#  [******           17%                  ]  472 of 2844 complete
#  [******           17%                  ]  473 of 2844 complete
#  [******           17%                  ]  474 of 2844 complete
#  [******           17%                  ]  475 of 2844 complete
#  [******           17%                  ]  476 of 2844 complete
#  [******           17%                  ]  477 of 2844 complete
#  [******           17%                  ]  478 of 2844 complete
#  [******           17%                  ]  479 of 2844 complete
#  [******           17%                  ]  480 of 2844 complete
#  [******           17%                  ]  481 of 2844 complete
#  [******           17%                  ]  482 of 2844 complete
#  [******           17%                  ]  483 of 2844 complete
#  [******           17%                  ]  484 of 2844 complete
#  [******           17%                  ]  485 of 2844 complete
#  [******           17%                  ]  486 of 2844 complete
#  [******           17%                  ]  487 of 2844 complete
#  [******           17%                  ]  488 of 2844 complete
#  [******           17%                  ]  489 of 2844 complete
#  [******           17%                  ]  490 of 2844 complete
#  [******           17%                  ]  491 of 2844 complete
#  [******           17%                  ]  492 of 2844 complete
#  [******           17%                  ]  493 of 2844 complete
#  [******           17%                  ]  494 of 2844 complete
#  [******           17%                  ]  495 of 2844 complete
#  [******           17%                  ]  496 of 2844 complete
#  [******           17%                  ]  497 of 2844 complete
#  [*******          18%                  ]  498 of 2844 complete
#  [*******          18%                  ]  499 of 2844 complete
#  [*******          18%                  ]  500 of 2844 complete
#  [*******          18%                  ]  501 of 2844 complete
#  [*******          18%                  ]  502 of 2844 complete
#  [*******          18%                  ]  503 of 2844 complete
#  [*******          18%                  ]  504 of 2844 complete
#  [*******          18%                  ]  505 of 2844 complete
#  [*******          18%                  ]  506 of 2844 complete
#  [*******          18%                  ]  507 of 2844 complete
#  [*******          18%                  ]  508 of 2844 complete
#  [*******          18%                  ]  509 of 2844 complete
#  [*******          18%                  ]  510 of 2844 complete
#  [*******          18%                  ]  511 of 2844 complete
#  [*******          18%                  ]  512 of 2844 complete
#  [*******          18%                  ]  513 of 2844 complete
#  [*******          18%                  ]  514 of 2844 complete
#  [*******          18%                  ]  515 of 2844 complete
#  [*******          18%                  ]  516 of 2844 complete
#  [*******          18%                  ]  517 of 2844 complete
#  [*******          18%                  ]  518 of 2844 complete
#  [*******          18%                  ]  519 of 2844 complete
#  [*******          18%                  ]  520 of 2844 complete
#  [*******          18%                  ]  521 of 2844 complete
#  [*******          18%                  ]  522 of 2844 complete
#  [*******          18%                  ]  523 of 2844 complete
#  [*******          18%                  ]  524 of 2844 complete
#  [*******          18%                  ]  525 of 2844 complete
#  [*******          18%                  ]  526 of 2844 complete
#  [*******          19%                  ]  527 of 2844 complete
#  [*******          19%                  ]  528 of 2844 complete
#  [*******          19%                  ]  529 of 2844 complete
#  [*******          19%                  ]  530 of 2844 complete
#  [*******          19%                  ]  531 of 2844 complete
#  [*******          19%                  ]  532 of 2844 complete
#  [*******          19%                  ]  533 of 2844 complete
#  [*******          19%                  ]  534 of 2844 complete
#  [*******          19%                  ]  535 of 2844 complete
#  [*******          19%                  ]  536 of 2844 complete
#  [*******          19%                  ]  537 of 2844 complete
#  [*******          19%                  ]  538 of 2844 complete
#  [*******          19%                  ]  539 of 2844 complete
#  [*******          19%                  ]  540 of 2844 complete
#  [*******          19%                  ]  541 of 2844 complete
#  [*******          19%                  ]  542 of 2844 complete
#  [*******          19%                  ]  543 of 2844 complete
#  [*******          19%                  ]  544 of 2844 complete
#  [*******          19%                  ]  545 of 2844 complete
#  [*******          19%                  ]  546 of 2844 complete
#  [*******          19%                  ]  547 of 2844 complete
#  [*******          19%                  ]  548 of 2844 complete
#  [*******          19%                  ]  549 of 2844 complete
#  [*******          19%                  ]  550 of 2844 complete
#  [*******          19%                  ]  551 of 2844 complete
#  [*******          19%                  ]  552 of 2844 complete
#  [*******          19%                  ]  553 of 2844 complete
#  [*******          19%                  ]  554 of 2844 complete
#  [********         20%                  ]  555 of 2844 complete
#  [********         20%                  ]  556 of 2844 complete
#  [********         20%                  ]  557 of 2844 complete
#  [********         20%                  ]  558 of 2844 complete
#  [********         20%                  ]  559 of 2844 complete
#  [********         20%                  ]  560 of 2844 complete
#  [********         20%                  ]  561 of 2844 complete
#  [********         20%                  ]  562 of 2844 complete
#  [********         20%                  ]  563 of 2844 complete
#  [********         20%                  ]  564 of 2844 complete
#  [********         20%                  ]  565 of 2844 complete
#  [********         20%                  ]  566 of 2844 complete
#  [********         20%                  ]  567 of 2844 complete
#  [********         20%                  ]  568 of 2844 complete
#  [********         20%                  ]  569 of 2844 complete
#  [********         20%                  ]  570 of 2844 complete
#  [********         20%                  ]  571 of 2844 complete
#  [********         20%                  ]  572 of 2844 complete
#  [********         20%                  ]  573 of 2844 complete
#  [********         20%                  ]  574 of 2844 complete
#  [********         20%                  ]  575 of 2844 complete
#  [********         20%                  ]  576 of 2844 complete
#  [********         20%                  ]  577 of 2844 complete
#  [********         20%                  ]  578 of 2844 complete
#  [********         20%                  ]  579 of 2844 complete
#  [********         20%                  ]  580 of 2844 complete
#  [********         20%                  ]  581 of 2844 complete
#  [********         20%                  ]  582 of 2844 complete
#  [********         20%                  ]  583 of 2844 complete
#  [********         21%                  ]  584 of 2844 complete
#  [********         21%                  ]  585 of 2844 complete
#  [********         21%                  ]  586 of 2844 complete
#  [********         21%                  ]  587 of 2844 complete
#  [********         21%                  ]  588 of 2844 complete
#  [********         21%                  ]  589 of 2844 complete
#  [********         21%                  ]  590 of 2844 complete
#  [********         21%                  ]  591 of 2844 complete
#  [********         21%                  ]  592 of 2844 complete
#  [********         21%                  ]  593 of 2844 complete
#  [********         21%                  ]  594 of 2844 complete
#  [********         21%                  ]  595 of 2844 complete
#  [********         21%                  ]  596 of 2844 complete
#  [********         21%                  ]  597 of 2844 complete
#  [********         21%                  ]  598 of 2844 complete
#  [********         21%                  ]  599 of 2844 complete
#  [********         21%                  ]  600 of 2844 complete
#  [********         21%                  ]  601 of 2844 complete
#  [********         21%                  ]  602 of 2844 complete
#  [********         21%                  ]  603 of 2844 complete
#  [********         21%                  ]  604 of 2844 complete
#  [********         21%                  ]  605 of 2844 complete
#  [********         21%                  ]  606 of 2844 complete
#  [********         21%                  ]  607 of 2844 complete
#  [********         21%                  ]  608 of 2844 complete
#  [********         21%                  ]  609 of 2844 complete
#  [********         21%                  ]  610 of 2844 complete
#  [********         21%                  ]  611 of 2844 complete
#  [********         22%                  ]  612 of 2844 complete
#  [********         22%                  ]  613 of 2844 complete
#  [********         22%                  ]  614 of 2844 complete
#  [********         22%                  ]  615 of 2844 complete
#  [********         22%                  ]  616 of 2844 complete
#  [********         22%                  ]  617 of 2844 complete
#  [********         22%                  ]  618 of 2844 complete
#  [********         22%                  ]  619 of 2844 complete
#  [********         22%                  ]  620 of 2844 complete
#  [********         22%                  ]  621 of 2844 complete
#  [********         22%                  ]  622 of 2844 complete
#  [********         22%                  ]  623 of 2844 complete
#  [********         22%                  ]  624 of 2844 complete
#  [********         22%                  ]  625 of 2844 complete
#  [********         22%                  ]  626 of 2844 complete
#  [********         22%                  ]  627 of 2844 complete
#  [********         22%                  ]  628 of 2844 complete
#  [********         22%                  ]  629 of 2844 complete
#  [********         22%                  ]  630 of 2844 complete
#  [********         22%                  ]  631 of 2844 complete
#  [********         22%                  ]  632 of 2844 complete
#  [********         22%                  ]  633 of 2844 complete
#  [********         22%                  ]  634 of 2844 complete
#  [********         22%                  ]  635 of 2844 complete
#  [********         22%                  ]  636 of 2844 complete
#  [********         22%                  ]  637 of 2844 complete
#  [********         22%                  ]  638 of 2844 complete
#  [********         22%                  ]  639 of 2844 complete
#  [*********        23%                  ]  640 of 2844 complete
#  [*********        23%                  ]  641 of 2844 complete
#  [*********        23%                  ]  642 of 2844 complete
#  [*********        23%                  ]  643 of 2844 complete
#  [*********        23%                  ]  644 of 2844 complete
#  [*********        23%                  ]  645 of 2844 complete
#  [*********        23%                  ]  646 of 2844 complete
#  [*********        23%                  ]  647 of 2844 complete
#  [*********        23%                  ]  648 of 2844 complete
#  [*********        23%                  ]  649 of 2844 complete
#  [*********        23%                  ]  650 of 2844 complete
#  [*********        23%                  ]  651 of 2844 complete
#  [*********        23%                  ]  652 of 2844 complete
#  [*********        23%                  ]  653 of 2844 complete
#  [*********        23%                  ]  654 of 2844 complete
#  [*********        23%                  ]  655 of 2844 complete
#  [*********        23%                  ]  656 of 2844 complete
#  [*********        23%                  ]  657 of 2844 complete
#  [*********        23%                  ]  658 of 2844 complete
#  [*********        23%                  ]  659 of 2844 complete
#  [*********        23%                  ]  660 of 2844 complete
#  [*********        23%                  ]  661 of 2844 complete
#  [*********        23%                  ]  662 of 2844 complete
#  [*********        23%                  ]  663 of 2844 complete
#  [*********        23%                  ]  664 of 2844 complete
#  [*********        23%                  ]  665 of 2844 complete
#  [*********        23%                  ]  666 of 2844 complete
#  [*********        23%                  ]  667 of 2844 complete
#  [*********        23%                  ]  668 of 2844 complete
#  [*********        24%                  ]  669 of 2844 complete
#  [*********        24%                  ]  670 of 2844 complete
#  [*********        24%                  ]  671 of 2844 complete
#  [*********        24%                  ]  672 of 2844 complete
#  [*********        24%                  ]  673 of 2844 complete
#  [*********        24%                  ]  674 of 2844 complete
#  [*********        24%                  ]  675 of 2844 complete
#  [*********        24%                  ]  676 of 2844 complete
#  [*********        24%                  ]  677 of 2844 complete
#  [*********        24%                  ]  678 of 2844 complete
#  [*********        24%                  ]  679 of 2844 complete
#  [*********        24%                  ]  680 of 2844 complete
#  [*********        24%                  ]  681 of 2844 complete
#  [*********        24%                  ]  682 of 2844 complete
#  [*********        24%                  ]  683 of 2844 complete
#  [*********        24%                  ]  684 of 2844 complete
#  [*********        24%                  ]  685 of 2844 complete
#  [*********        24%                  ]  686 of 2844 complete
#  [*********        24%                  ]  687 of 2844 complete
#  [*********        24%                  ]  688 of 2844 complete
#  [*********        24%                  ]  689 of 2844 complete
#  [*********        24%                  ]  690 of 2844 complete
#  [*********        24%                  ]  691 of 2844 complete
#  [*********        24%                  ]  692 of 2844 complete
#  [*********        24%                  ]  693 of 2844 complete
#  [*********        24%                  ]  694 of 2844 complete
#  [*********        24%                  ]  695 of 2844 complete
#  [*********        24%                  ]  696 of 2844 complete
#  [**********       25%                  ]  697 of 2844 complete
#  [**********       25%                  ]  698 of 2844 complete
#  [**********       25%                  ]  699 of 2844 complete
#  [**********       25%                  ]  700 of 2844 complete
#  [**********       25%                  ]  701 of 2844 complete
#  [**********       25%                  ]  702 of 2844 complete
#  [**********       25%                  ]  703 of 2844 complete
#  [**********       25%                  ]  704 of 2844 complete
#  [**********       25%                  ]  705 of 2844 complete
#  [**********       25%                  ]  706 of 2844 complete
#  [**********       25%                  ]  707 of 2844 complete
#  [**********       25%                  ]  708 of 2844 complete
#  [**********       25%                  ]  709 of 2844 complete
#  [**********       25%                  ]  710 of 2844 complete
#  [**********       25%                  ]  711 of 2844 complete
#  [**********       25%                  ]  712 of 2844 complete
#  [**********       25%                  ]  713 of 2844 complete
#  [**********       25%                  ]  714 of 2844 complete
#  [**********       25%                  ]  715 of 2844 complete
#  [**********       25%                  ]  716 of 2844 complete
#  [**********       25%                  ]  717 of 2844 complete
#  [**********       25%                  ]  718 of 2844 complete
#  [**********       25%                  ]  719 of 2844 complete
#  [**********       25%                  ]  720 of 2844 complete
#  [**********       25%                  ]  721 of 2844 complete
#  [**********       25%                  ]  722 of 2844 complete
#  [**********       25%                  ]  723 of 2844 complete
#  [**********       25%                  ]  724 of 2844 complete
#  [**********       25%                  ]  725 of 2844 complete
#  [**********       26%                  ]  726 of 2844 complete
#  [**********       26%                  ]  727 of 2844 complete
#  [**********       26%                  ]  728 of 2844 complete
#  [**********       26%                  ]  729 of 2844 complete
#  [**********       26%                  ]  730 of 2844 complete
#  [**********       26%                  ]  731 of 2844 complete
#  [**********       26%                  ]  732 of 2844 complete
#  [**********       26%                  ]  733 of 2844 complete
#  [**********       26%                  ]  734 of 2844 complete
#  [**********       26%                  ]  735 of 2844 complete
#  [**********       26%                  ]  736 of 2844 complete
#  [**********       26%                  ]  737 of 2844 complete
#  [**********       26%                  ]  738 of 2844 complete
#  [**********       26%                  ]  739 of 2844 complete
#  [**********       26%                  ]  740 of 2844 complete
#  [**********       26%                  ]  741 of 2844 complete
#  [**********       26%                  ]  742 of 2844 complete
#  [**********       26%                  ]  743 of 2844 complete
#  [**********       26%                  ]  744 of 2844 complete
#  [**********       26%                  ]  745 of 2844 complete
#  [**********       26%                  ]  746 of 2844 complete
#  [**********       26%                  ]  747 of 2844 complete
#  [**********       26%                  ]  748 of 2844 complete
#  [**********       26%                  ]  749 of 2844 complete
#  [**********       26%                  ]  750 of 2844 complete
#  [**********       26%                  ]  751 of 2844 complete
#  [**********       26%                  ]  752 of 2844 complete
# ...
#  [*****************93%***************   ]  2634 of 2844 complete
#  [*****************93%***************   ]  2635 of 2844 complete
#  [*****************93%***************   ]  2636 of 2844 complete
#  [*****************93%***************   ]  2637 of 2844 complete
#  [*****************93%***************   ]  2638 of 2844 complete
#  [*****************93%***************   ]  2639 of 2844 complete
#  [*****************93%***************   ]  2640 of 2844 complete
#  [*****************93%***************   ]  2641 of 2844 complete
#  [*****************93%***************   ]  2642 of 2844 complete
#  [*****************93%***************   ]  2643 of 2844 complete
#  [*****************93%***************   ]  2644 of 2844 complete
#  [*****************93%***************   ]  2645 of 2844 complete
#  [*****************93%***************   ]  2646 of 2844 complete
#  [*****************93%***************   ]  2647 of 2844 complete
#  [*****************93%***************   ]  2648 of 2844 complete
#  [*****************93%***************   ]  2649 of 2844 complete
#  [*****************93%***************   ]  2650 of 2844 complete
#  [*****************93%***************   ]  2651 of 2844 complete
#  [*****************93%***************   ]  2652 of 2844 complete
#  [*****************93%***************   ]  2653 of 2844 complete
#  [*****************93%***************   ]  2654 of 2844 complete
#  [*****************93%***************   ]  2655 of 2844 complete
#  [*****************93%***************   ]  2656 of 2844 complete
#  [*****************93%***************   ]  2657 of 2844 complete
#  [*****************93%***************   ]  2658 of 2844 complete
#  [*****************93%***************   ]  2659 of 2844 complete
#  [*****************94%****************  ]  2660 of 2844 complete
#  [*****************94%****************  ]  2661 of 2844 complete
#  [*****************94%****************  ]  2662 of 2844 complete
#  [*****************94%****************  ]  2663 of 2844 complete
#  [*****************94%****************  ]  2664 of 2844 complete
#  [*****************94%****************  ]  2665 of 2844 complete
#  [*****************94%****************  ]  2666 of 2844 complete
#  [*****************94%****************  ]  2667 of 2844 complete
#  [*****************94%****************  ]  2668 of 2844 complete
#  [*****************94%****************  ]  2669 of 2844 complete
#  [*****************94%****************  ]  2670 of 2844 complete
#  [*****************94%****************  ]  2671 of 2844 complete
#  [*****************94%****************  ]  2672 of 2844 complete
#  [*****************94%****************  ]  2673 of 2844 complete
#  [*****************94%****************  ]  2674 of 2844 complete
#  [*****************94%****************  ]  2675 of 2844 complete
#  [*****************94%****************  ]  2676 of 2844 complete
#  [*****************94%****************  ]  2677 of 2844 complete
#  [*****************94%****************  ]  2678 of 2844 complete
#  [*****************94%****************  ]  2679 of 2844 complete
#  [*****************94%****************  ]  2680 of 2844 complete
#  [*****************94%****************  ]  2681 of 2844 complete
#  [*****************94%****************  ]  2682 of 2844 complete
#  [*****************94%****************  ]  2683 of 2844 complete
#  [*****************94%****************  ]  2684 of 2844 complete
#  [*****************94%****************  ]  2685 of 2844 complete
#  [*****************94%****************  ]  2686 of 2844 complete
#  [*****************94%****************  ]  2687 of 2844 complete
#  [*****************95%****************  ]  2688 of 2844 complete
#  [*****************95%****************  ]  2689 of 2844 complete
#  [*****************95%****************  ]  2690 of 2844 complete
#  [*****************95%****************  ]  2691 of 2844 complete
#  [*****************95%****************  ]  2692 of 2844 complete
#  [*****************95%****************  ]  2693 of 2844 complete
#  [*****************95%****************  ]  2694 of 2844 complete
#  [*****************95%****************  ]  2695 of 2844 complete
#  [*****************95%****************  ]  2696 of 2844 complete
#  [*****************95%****************  ]  2697 of 2844 complete
#  [*****************95%****************  ]  2698 of 2844 complete
#  [*****************95%****************  ]  2699 of 2844 complete
#  [*****************95%****************  ]  2700 of 2844 complete
#  [*****************95%****************  ]  2701 of 2844 complete
#  [*****************95%****************  ]  2702 of 2844 complete
#  [*****************95%****************  ]  2703 of 2844 complete
#  [*****************95%****************  ]  2704 of 2844 complete
#  [*****************95%****************  ]  2705 of 2844 complete
#  [*****************95%****************  ]  2706 of 2844 complete
#  [*****************95%****************  ]  2707 of 2844 complete
#  [*****************95%****************  ]  2708 of 2844 complete
#  [*****************95%****************  ]  2709 of 2844 complete
#  [*****************95%****************  ]  2710 of 2844 complete
#  [*****************95%****************  ]  2711 of 2844 complete
#  [*****************95%****************  ]  2712 of 2844 complete
#  [*****************95%****************  ]  2713 of 2844 complete
#  [*****************95%****************  ]  2714 of 2844 complete
#  [*****************95%****************  ]  2715 of 2844 complete
#  [*****************95%****************  ]  2716 of 2844 complete
#  [*****************96%****************  ]  2717 of 2844 complete
#  [*****************96%****************  ]  2718 of 2844 complete
#  [*****************96%****************  ]  2719 of 2844 complete
#  [*****************96%****************  ]  2720 of 2844 complete
#  [*****************96%****************  ]  2721 of 2844 complete
#  [*****************96%****************  ]  2722 of 2844 complete
#  [*****************96%****************  ]  2723 of 2844 complete
#  [*****************96%****************  ]  2724 of 2844 complete
#  [*****************96%****************  ]  2725 of 2844 complete
#  [*****************96%****************  ]  2726 of 2844 complete
#  [*****************96%****************  ]  2727 of 2844 complete
#  [*****************96%****************  ]  2728 of 2844 complete
#  [*****************96%****************  ]  2729 of 2844 complete
#  [*****************96%****************  ]  2730 of 2844 complete
#  [*****************96%****************  ]  2731 of 2844 complete
#  [*****************96%****************  ]  2732 of 2844 complete
#  [*****************96%****************  ]  2733 of 2844 complete
#  [*****************96%****************  ]  2734 of 2844 complete
#  [*****************96%****************  ]  2735 of 2844 complete
#  [*****************96%****************  ]  2736 of 2844 complete
#  [*****************96%****************  ]  2737 of 2844 complete
#  [*****************96%****************  ]  2738 of 2844 complete
#  [*****************96%****************  ]  2739 of 2844 complete
#  [*****************96%****************  ]  2740 of 2844 complete
#  [*****************96%****************  ]  2741 of 2844 complete
#  [*****************96%****************  ]  2742 of 2844 complete
#  [*****************96%****************  ]  2743 of 2844 complete
#  [*****************96%****************  ]  2744 of 2844 complete
#  [*****************97%***************** ]  2745 of 2844 complete
#  [*****************97%***************** ]  2746 of 2844 complete
#  [*****************97%***************** ]  2747 of 2844 complete
#  [*****************97%***************** ]  2748 of 2844 complete
#  [*****************97%***************** ]  2749 of 2844 complete
#  [*****************97%***************** ]  2750 of 2844 complete
#  [*****************97%***************** ]  2751 of 2844 complete
#  [*****************97%***************** ]  2752 of 2844 complete
#  [*****************97%***************** ]  2753 of 2844 complete
#  [*****************97%***************** ]  2754 of 2844 complete
#  [*****************97%***************** ]  2755 of 2844 complete
#  [*****************97%***************** ]  2756 of 2844 complete
#  [*****************97%***************** ]  2757 of 2844 complete
#  [*****************97%***************** ]  2758 of 2844 complete
#  [*****************97%***************** ]  2759 of 2844 complete
#  [*****************97%***************** ]  2760 of 2844 complete
#  [*****************97%***************** ]  2761 of 2844 complete
#  [*****************97%***************** ]  2762 of 2844 complete
#  [*****************97%***************** ]  2763 of 2844 complete
#  [*****************97%***************** ]  2764 of 2844 complete
#  [*****************97%***************** ]  2765 of 2844 complete
#  [*****************97%***************** ]  2766 of 2844 complete
#  [*****************97%***************** ]  2767 of 2844 complete
#  [*****************97%***************** ]  2768 of 2844 complete
#  [*****************97%***************** ]  2769 of 2844 complete
#  [*****************97%***************** ]  2770 of 2844 complete
#  [*****************97%***************** ]  2771 of 2844 complete
#  [*****************97%***************** ]  2772 of 2844 complete
#  [*****************98%***************** ]  2773 of 2844 complete
#  [*****************98%***************** ]  2774 of 2844 complete
#  [*****************98%***************** ]  2775 of 2844 complete
#  [*****************98%***************** ]  2776 of 2844 complete
#  [*****************98%***************** ]  2777 of 2844 complete
#  [*****************98%***************** ]  2778 of 2844 complete
#  [*****************98%***************** ]  2779 of 2844 complete
#  [*****************98%***************** ]  2780 of 2844 complete
#  [*****************98%***************** ]  2781 of 2844 complete
#  [*****************98%***************** ]  2782 of 2844 complete
#  [*****************98%***************** ]  2783 of 2844 complete
#  [*****************98%***************** ]  2784 of 2844 complete
#  [*****************98%***************** ]  2785 of 2844 complete
#  [*****************98%***************** ]  2786 of 2844 complete
#  [*****************98%***************** ]  2787 of 2844 complete
#  [*****************98%***************** ]  2788 of 2844 complete
#  [*****************98%***************** ]  2789 of 2844 complete
#  [*****************98%***************** ]  2790 of 2844 complete
#  [*****************98%***************** ]  2791 of 2844 complete
#  [*****************98%***************** ]  2792 of 2844 complete
#  [*****************98%***************** ]  2793 of 2844 complete
#  [*****************98%***************** ]  2794 of 2844 complete
#  [*****************98%***************** ]  2795 of 2844 complete
#  [*****************98%***************** ]  2796 of 2844 complete
#  [*****************98%***************** ]  2797 of 2844 complete
#  [*****************98%***************** ]  2798 of 2844 complete
#  [*****************98%***************** ]  2799 of 2844 complete
#  [*****************98%***************** ]  2800 of 2844 complete
#  [*****************98%***************** ]  2801 of 2844 complete
#  [*****************99%******************]  2802 of 2844 complete
#  [*****************99%******************]  2803 of 2844 complete
#  [*****************99%******************]  2804 of 2844 complete
#  [*****************99%******************]  2805 of 2844 complete
#  [*****************99%******************]  2806 of 2844 complete
#  [*****************99%******************]  2807 of 2844 complete
#  [*****************99%******************]  2808 of 2844 complete
#  [*****************99%******************]  2809 of 2844 complete
#  [*****************99%******************]  2810 of 2844 complete
#  [*****************99%******************]  2811 of 2844 complete
#  [*****************99%******************]  2812 of 2844 complete
#  [*****************99%******************]  2813 of 2844 complete
#  [*****************99%******************]  2814 of 2844 complete
#  [*****************99%******************]  2815 of 2844 complete
#  [*****************99%******************]  2816 of 2844 complete
#  [*****************99%******************]  2817 of 2844 complete
#  [*****************99%******************]  2818 of 2844 complete
#  [*****************99%******************]  2819 of 2844 complete
#  [*****************99%******************]  2820 of 2844 complete
#  [*****************99%******************]  2821 of 2844 complete
#  [*****************99%******************]  2822 of 2844 complete
#  [*****************99%******************]  2823 of 2844 complete
#  [*****************99%******************]  2824 of 2844 complete
#  [*****************99%******************]  2825 of 2844 complete
#  [*****************99%******************]  2826 of 2844 complete
#  [*****************99%******************]  2827 of 2844 complete
#  [*****************99%******************]  2828 of 2844 complete
#  [*****************99%******************]  2829 of 2844 complete
#  [****************100%******************]  2830 of 2844 complete
#  [****************100%******************]  2831 of 2844 complete
#  [****************100%******************]  2832 of 2844 complete
#  [****************100%******************]  2833 of 2844 complete
#  [****************100%******************]  2834 of 2844 complete
#  [****************100%******************]  2835 of 2844 complete
#  [****************100%******************]  2836 of 2844 complete
#  [****************100%******************]  2837 of 2844 complete
#  [****************100%******************]  2838 of 2844 complete
#  [****************100%******************]  2839 of 2844 complete
#  [****************100%******************]  2840 of 2844 complete
#  [****************100%******************]  2841 of 2844 complete
#  [****************100%******************]  2842 of 2844 complete
#  [****************100%******************]  2843 of 2844 complete
#  [****************100%******************]  2844 of 2844 complete
# [[  454.39130435  1748.0625      1855.56       ...,   767.10526316
#    2538.36666667   805.82352941]
#  [  411.30434783  1285.3125      1475.44       ...,   581.78947368  2159.5
#     599.52941176]
#  [  917.43478261   543.65625      664.88       ...,   651.42105263  1291.9
#     685.52941176]
#  ...,
#  [ 1439.56521739   646.40625      642.68       ...,  1050.89473684
#     761.63333333   972.17647059]
#  [  942.7826087    656.46875      697.84       ...,   682.10526316
#    1084.43333333   677.82352941]
#  [ 1907.          1055.5625       946.8        ...,  1591.36842105
#     823.06666667  1488.11764706]]
# [[ 4]
#  [ 4]
#  [ 3]
#  [ 1]
#  [ 0]
#  [ 5]
#  [ 4]
#  [ 2]
#  [ 5]
#  [ 4]
#  [ 4]
#  [ 6]
#  [ 6]
#  [ 5]
#  [ 4]
#  [ 5]
#  [ 6]
#  [ 6]
#  [ 0]
#  [ 2]
#  [ 4]
#  [11]
#  [ 9]
#  [ 5]
#  [ 2]
#  [ 6]
#  [11]
#  [ 0]
#  [ 6]
#  [ 9]
#  [ 3]
#  [ 6]
#  [ 9]
#  [ 3]
#  [ 3]
#  [ 6]
#  [ 2]
#  [ 4]
#  [ 9]
#  [ 6]
#  [ 3]
#  [11]
#  [ 4]
#  [ 4]
#  [ 3]
#  [ 9]
#  [ 5]
#  [11]
#  [ 1]
#  [ 2]
#  [ 1]
#  [ 6]
#  [ 7]
#  [10]
#  [ 7]
#  [ 3]
#  [11]
#  [ 5]
#  [ 4]
#  [ 4]
#  [ 3]
#  [ 3]
#  [ 9]
#  [ 5]
#  [ 4]
#  [ 5]
#  [ 4]
#  [ 4]
#  [11]
#  [11]
#  [ 3]
#  [ 3]
#  [ 9]
#  [ 6]
#  [ 3]
#  [ 1]
#  [11]
#  [11]
#  [ 1]
#  [ 3]
#  [11]
#  [11]
#  [ 9]
#  [ 2]
#  [ 2]
#  [ 2]
#  [ 9]
#  [ 3]
#  [ 0]
#  [ 0]
#  [10]
#  [ 3]
#  [ 3]
#  [ 2]
#  [ 2]
#  [ 9]
#  [11]
#  [ 9]
#  [10]
#  [ 0]
#  [ 1]
#  [ 1]
#  [ 3]
#  [ 9]
#  [ 1]
#  [ 1]
#  [ 1]
#  [ 9]
#  [ 9]
#  [ 1]
#  [ 0]
#  [11]
#  [11]
#  [ 3]
#  [10]
#  [ 1]
#  [ 9]
#  [ 2]
#  [ 1]
#  [ 2]
#  [ 9]
#  [11]
#  [ 9]
#  [ 3]
#  [11]
#  [11]
#  [ 2]
#  [ 2]
#  [ 9]
#  [ 3]
#  [ 3]
#  [ 8]
#  [ 2]
#  [ 8]
#  [ 8]
#  [ 1]
#  [10]
#  [10]
#  [ 8]
#  [ 8]
#  [ 8]
#  [ 8]
#  [10]
#  [ 3]
#  [ 3]
#  [ 8]
#  [ 1]
#  [ 1]
#  [ 1]
#  [ 8]
#  [ 8]
#  [ 1]
#  [ 3]
#  [10]
#  [10]
#  [ 8]
#  [ 8]
#  [ 8]
#  [ 7]
#  [ 2]
#  [10]
#  [10]
#  [ 1]
#  [ 3]
#  [ 3]
#  [ 3]
#  [ 2]
#  [ 8]
#  [10]
#  [10]
#  [ 1]
#  [ 2]
#  [ 8]
#  [ 3]
#  [ 3]
#  [ 2]
#  [ 7]
#  [ 3]
#  [ 2]
#  [ 1]
#  [ 7]
#  [ 8]
#  [ 3]
#  [ 8]
#  [ 2]
#  [ 3]
#  [10]
#  [ 1]
#  [ 7]
#  [10]
#  [ 3]
#  [ 3]
#  [ 1]
#  [ 8]
#  [ 3]
#  [ 8]
#  [ 8]
#  [ 1]
#  [ 8]
#  [ 7]
#  [ 1]
#  [10]
#  [ 7]
#  [ 8]
#  [10]
#  [ 8]
#  [ 1]
#  [ 8]
#  [ 1]
#  [ 8]
#  [ 1]
#  [10]
#  [ 1]
#  [ 8]
#  [ 8]
#  [10]
#  [ 7]
#  [ 8]
#  [10]
#  [ 7]
#  [ 3]
#  [ 2]
#  [ 3]
#  [ 7]
#  [ 1]
#  [10]
#  [ 8]
#  [ 7]
#  [ 1]
#  [ 3]
#  [ 7]
#  [ 1]
#  [ 1]
#  [ 7]
#  [ 2]
#  [ 3]
#  [10]]
# /home/redrabbit/.pyenvs/pyquant/lib/python3.5/site-packages/scipy/stats/stats.py:249: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)

# %% [markdown]
# ### Resultados KNN-DTW
#
# O código a seguir, apresenta os resultados da classificação para o método KNN-DTW através de uma matriz de confusão que indica os erros de classificação do método.
#
# #### Interpretação da Matriz de Confusão (Confusion matrix)
#
# A diagonal principal indica o número de acertos do método. As diagonais de fora, indicam os itens que foram classificados para uma classe diferente. A cor representa a proporção dos erros/acertos com relação ao total de amostras do conjunto de testes.

# %%
from matplotlib import cm
from sklearn.metrics import classification_report, confusion_matrix

print (classification_report(y_test[::step], label))

used_labels = ['square', 'triangle', 'bar']
nused = len(used_labels)
conf_mat = confusion_matrix(y_test[::step], label, labels=used_labels)

fig = plt.figure(figsize=(nused,nused))
width = np.shape(conf_mat)[1]
height = np.shape(conf_mat)[0]

res = plt.imshow(np.array(conf_mat), cmap=cm.summer, interpolation='nearest')
for i, row in enumerate(conf_mat):
    for j, c in enumerate(row):
        if c>0:
            plt.text(j-.2, i+.1, c, fontsize=16)
            
cb = fig.colorbar(res)
plt.title('Confusion Matrix')
_ = plt.xticks(range(nused), used_labels, rotation=90)
_ = plt.yticks(range(nused), used_labels)
# Out:
#              precision    recall  f1-score   support
#
#         bar       0.81      0.73      0.77       108
#      square       0.88      0.54      0.67        69
#    triangle       0.43      0.70      0.54        60
#
# avg / total       0.73      0.67      0.68       237

# %%
print (x_test.shape, label.shape, y_test.shape, ((y_test == 'square') * (label == 'square')).shape)


filt= lambda nm: ((y_test == nm) * (label == nm))
ifilt= lambda nm: ((y_test == nm) * (label != nm))

matches = x_test[filt('square'), :]
plt.figure(); _ = plt.plot(matches.T, '.')
plt.title("square")
matches = x_test[ifilt('square'), :]
plt.figure(); _ = plt.plot(matches.T, '.')
plt.title("square erro")

matches = x_test[filt('triangle'), :]
plt.figure(); _ = plt.plot(matches.T, '.')
plt.title("triangle")
matches = x_test[ifilt('triangle'), :]
plt.figure(); _ = plt.plot(matches.T, '.')
plt.title("triangle erro")

matches = x_test[filt('bar'), :]
plt.figure(); _ = plt.plot(matches.T, '.', label='bar')
plt.title("bar")
matches = x_test[ifilt('bar'), :]
plt.figure(); _ = plt.plot(matches.T, '.', label='bar erro')
plt.title("bar erro")
# Out:
# (237, 1683) (237,) (237,) (237,)

# %% [markdown]
# ### Decision Tree Classifier
#
# Classificação utilizando a técnica de DTC, que é indicada para problemas em que a estrutura do dado não é fixa. No caso deste problema, é uma série temporal que começa e termina em instantes diferentes para casa exemplo.

# %%
from sklearn import tree

clf = tree.DecisionTreeClassifier()
clf = clf.fit(x_train, y_train)

# %%
y_result = clf.predict(x_test)

print (classification_report(y_test[::step], y_result))

used_labels = ['square', 'triangle', 'bar']
nused = len(used_labels)
conf_mat = confusion_matrix(y_test[::step], y_result, labels=used_labels)

fig = plt.figure(figsize=(nused,nused))
width = np.shape(conf_mat)[1]
height = np.shape(conf_mat)[0]

res = plt.imshow(np.array(conf_mat), cmap=cm.summer, interpolation='nearest')
for i, row in enumerate(conf_mat):
    for j, c in enumerate(row):
        if c>0:
            plt.text(j-.2, i+.1, c, fontsize=16)
            
cb = fig.colorbar(res)
plt.title('Confusion Matrix')
_ = plt.xticks(range(nused), used_labels, rotation=90)
_ = plt.yticks(range(nused), used_labels)

# %%
from sklearn.metrics import classification_report
y_true = [0, 1, 2, 1, 2]
y_pred = [0, 0, 2, 2, 1]
target_names = ['class 0', 'class 1', 'class 2']
print(classification_report(y_true, y_pred, target_names=target_names))

# %%
fig = plt.figure(figsize=(12, 6))
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)
mu = np.mean(x_train, axis=0)
sd = np.std(x_train, axis=0)
x_train_d = (x_train-mu)
_ = ax1.plot(x_train_d[y_train == 'square',:].T, '.', label='square')
_ = ax2.plot(x_train_d[y_train == 'triangle',:].T, '.', label='triangle') 
_ = ax3.plot(x_train_d[y_train == 'bar',:].T, '.', label='bar')
